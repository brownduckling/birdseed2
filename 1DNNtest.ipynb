# %%
""
1D NN test
manual optimize coefficient and bias

""

# %%
import matplotlib.pyplot as plt
import numpy as np

def outfn(x):
    return (1+np.tanh(x))/2

num=100

x1=np.linspace(-10,10,num)
x2=np.random.rand(num)
plt.plot(x1,outfn(x1))
plt.show()

# %%
def classify(x):
    return ((x-.5)/abs(x-.5)+1)/2
classify(.55)
# Out:
# 1.0

# %%
y2=[classify(x) for x in x2]

# %%
#neuro
a1=0.5; a2=0.5 
def cellout(x):
    return outfn(a1*x+a2)

# %%
plt.plot(x1,classify(x1),x1,cellout(x1))
plt.show()

# %%
delta=[classify(x)-cellout(x) for x in x1]
epsilon=1e-1
a2=a2+epsilon*np.sum(delta)
plt.plot(x1,classify(x1),x1,cellout(x1))
plt.show()

# %%
delta=[classify(x)-cellout(x) for x in x1]
epsilon=1e-1
a1=a1+epsilon*np.dot(delta,x1)
plt.plot(x1,classify(x1),x1,cellout(x1))
plt.show()

# %%
epsilon*np.dot(delta,x1)
# Out:
# 0.81460328733997533

# %%
plt.plot(x1,classify(x2),x1,cellout(x2))
plt.show()

# %%
a1,a2= 0.5,0.5
plt.plot(x1,classify(x2),x1,cellout(x2))
plt.show()

# %%
print('a1={0},a2={1}'.format(a1,a2))
# Out:
# a1=2.128481825285471,a2=-0.6020677311192718

# %%
a2
# Out:
# -0.60206773111927181
